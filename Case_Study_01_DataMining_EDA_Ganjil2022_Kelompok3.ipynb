# %% [markdown]
# # **Study Case 01 - Data Mining dan Business Intelligence: EDA pada data property**

# %%
import warnings; warnings.simplefilter('ignore')
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
import matplotlib.cm as cm
from collections import Counter
import scipy, itertools
from scipy import stats
from sklearn.preprocessing import StandardScaler, MinMaxScaler
plt.style.use('bmh'); sns.set()
import requests
import io
from pandas_profiling import ProfileReport

# %% [markdown]
# # **Load data file csv dari akun GitHub**

# %%
# Loading Data:

try: # Running Locally, yakinkan "file_" berada di folder "data"
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')
except: # Running in Google Colab
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/DataMining-CaseStudies/main/data/jakarta.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/DataMining-CaseStudies/main/data/depok.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/DataMining-CaseStudies/main/data/tangerang.csv
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')
    
dfJ.shape, dfD.shape, dfT.shape
# Out:
# ((1024, 26), (998, 26), (128, 26))

# %% [markdown]
# # **Treatment Data Jakarta**

# %% [markdown]
# # Data Understanding

# %%
N, P = dfJ.shape # Ukuran Data
print('baris = ', N, ', Kolom (jumlah variabel) = ', P)
print("Tipe Variabe df = ", type(dfJ))
# "Melihat" beberapa data pertamanya
dfJ.head()
# Out:
# baris =  1024 , Kolom (jumlah variabel) =  26
# Tipe Variabe df =  <class 'pandas.core.frame.DataFrame'>
#    created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0  06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1  02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2  06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3  06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4  06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
#
#   sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 1        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 2        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 3        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 4        SHM   2200.0  ...         NaN          NaN         NaN         NaN
#
#    Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 25
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 26 columns]

# %%
dfJ.tail()
# Out:
#      created_at  LT  LB  KT  KM  garasi  carport lokasi sertifikat  listrik  \
# 1019        NaN NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 1020        NaN NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 1021        NaN NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 1022        NaN NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 1023        NaN NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
#
#       ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  Unnamed: 20  \
# 1019  ...         NaN          NaN         NaN         NaN          NaN
# 1020  ...         NaN          NaN         NaN         NaN          NaN
# 1021  ...         NaN          NaN         NaN         NaN          NaN
# 1022  ...         NaN          NaN         NaN         NaN          NaN
# 1023  ...         NaN          NaN         NaN         NaN          NaN
#
#       Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 1019          NaN          NaN          NaN          NaN          NaN
# 1020          NaN          NaN          NaN          NaN          NaN
# 1021          NaN          NaN          NaN          NaN          NaN
# 1022          NaN          NaN          NaN          NaN          NaN
# 1023          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %%
dfJ.sample(15)
# Out:
#       created_at     LT      LB   KT   KM  garasi  carport          lokasi  \
# 377          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 288          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 865          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 895          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 95    07-12-2021  640.0  1200.0  6.0  5.0     NaN      2.0  Jakarta Utara
# 1008         NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 74    06-12-2021  170.0   325.0  5.0  4.0     2.0      2.0  Jakarta Utara
# 750          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 742          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 188          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 565          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 894          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 737          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 315          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
# 310          NaN    NaN     NaN  NaN  NaN     NaN      NaN             NaN
#
#      sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18  \
# 377         NaN      NaN  ...         NaN          NaN         NaN
# 288         NaN      NaN  ...         NaN          NaN         NaN
# 865         NaN      NaN  ...         NaN          NaN         NaN
# 895         NaN      NaN  ...         NaN          NaN         NaN
# 95          SHM   9500.0  ...         NaN          NaN         NaN
# 1008        NaN      NaN  ...         NaN          NaN         NaN
# 74          SHM   3500.0  ...         NaN          NaN         NaN
# 750         NaN      NaN  ...         NaN          NaN         NaN
# 742         NaN      NaN  ...         NaN          NaN         NaN
# 188         NaN      NaN  ...         NaN          NaN         NaN
# 565         NaN      NaN  ...         NaN          NaN         NaN
# 894         NaN      NaN  ...         NaN          NaN         NaN
# 737         NaN      NaN  ...         NaN          NaN         NaN
# 315         NaN      NaN  ...         NaN          NaN         NaN
# 310         NaN      NaN  ...         NaN          NaN         NaN
#
#      Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 377          NaN          NaN          NaN          NaN          NaN
# 288          NaN          NaN          NaN          NaN          NaN
# 865          NaN          NaN          NaN          NaN          NaN
# 895          NaN          NaN          NaN          NaN          NaN
# 95           NaN          NaN          NaN          NaN          NaN
# 1008         NaN          NaN          NaN          NaN          NaN
# 74           NaN          NaN          NaN          NaN          NaN
# 750          NaN          NaN          NaN          NaN          NaN
# 742          NaN          NaN          NaN          NaN          NaN
# 188          NaN          NaN          NaN          NaN          NaN
# 565          NaN          NaN          NaN          NaN          NaN
# 894          NaN          NaN          NaN          NaN          NaN
# 737          NaN          NaN          NaN          NaN          NaN
# 315          NaN          NaN          NaN          NaN          NaN
# 310          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 24  Unnamed: 25
# 377           NaN          NaN
# 288           NaN          NaN
# 865           NaN          NaN
# 895           NaN          NaN
# 95            NaN          NaN
# 1008          NaN          NaN
# 74            NaN          NaN
# 750           NaN          NaN
# 742           NaN          NaN
# 188           NaN          NaN
# 565           NaN          NaN
# 894           NaN          NaN
# 737           NaN          NaN
# 315           NaN          NaN
# 310           NaN          NaN
#
# [15 rows x 26 columns]

# %%
# drop kolom yang tidak terpakai
dfJ.drop(["created_at","Unnamed: 14","Unnamed: 15","Unnamed: 16","Unnamed: 17","Unnamed: 18",
          "Unnamed: 19","Unnamed: 20","Unnamed: 21","Unnamed: 22","Unnamed: 23",
          "Unnamed: 24","Unnamed: 25"], axis=1, inplace=True)
dfJ.head()
# Out:
#       LT     LB   KT   KM  garasi  carport         lokasi sertifikat  listrik  \
# 0  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat        SHM   2200.0
# 1   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat        SHM   2200.0
# 2   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat        SHM   2200.0
# 3   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat        SHM   2200.0
# 4   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat        SHM   2200.0
#
#   hadap         harga                                                URL  \
# 0   NaN  4.500000e+09  https://www.rumah.com/listing-properti/dijual-...
# 1   NaN  1.100000e+09  https://www.rumah.com/listing-properti/dijual-...
# 2   NaN  3.950000e+08  https://www.rumah.com/listing-properti/dijual-...
# 3   NaN  8.350000e+08  https://www.rumah.com/listing-properti/dijual-...
# 4   NaN  1.100000e+09  https://www.rumah.com/listing-properti/dijual-...
#
#                                            deskripsi
# 0  Dekat Cikini Salemba Taman Isamail Marzuki Kam...
# 1  Mengusung konsep minimalis, dan didukung denga...
# 2  Dekat dengan Mall Atrium Senen, dekat dengan a...
# 3  Berlokasi sangat strategis, sangat dekat ke Tu...
# 4  Bisa request ubah tata ruang, beli 2 unit mend...

# %%
dfJ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LT          121 non-null    float64
#  1   LB          121 non-null    float64
#  2   KT          121 non-null    float64
#  3   KM          121 non-null    float64
#  4   garasi      44 non-null     float64
#  5   carport     90 non-null     float64
#  6   lokasi      121 non-null    object
#  7   sertifikat  119 non-null    object
#  8   listrik     120 non-null    float64
#  9   hadap       36 non-null     object
#  10  harga       121 non-null    float64
#  11  URL         121 non-null    object
#  12  deskripsi   112 non-null    object
# dtypes: float64(8), object(5)
# memory usage: 104.1+ KB

# %%
dfJ.drop(dfJ.tail(903).index,inplace=True)

# %%
dfJ
# Out:
#         LT     LB   KT   KM  garasi  carport         lokasi sertifikat  \
# 0    202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat        SHM
# 1     30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat        SHM
# 2     19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat        SHM
# 3     33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat        SHM
# 4     30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat        SHM
# ..     ...    ...  ...  ...     ...      ...            ...        ...
# 116  220.0  239.0  5.0  4.0     1.0      2.0  Jakarta Timur       PPJB
# 117   70.0   57.0  3.0  2.0     NaN      2.0  Jakarta Timur        SHM
# 118  315.0  280.0  4.0  3.0     1.0      2.0  Jakarta Timur  SHM + IMB
# 119  135.0  190.0  5.0  5.0     NaN      2.0  Jakarta Timur  SHM + IMB
# 120  144.0  250.0  5.0  5.0     NaN      2.0  Jakarta Timur        SHM
#
#      listrik    hadap         harga  \
# 0     2200.0      NaN  4.500000e+09
# 1     2200.0      NaN  1.100000e+09
# 2     2200.0      NaN  3.950000e+08
# 3     2200.0      NaN  8.350000e+08
# 4     2200.0      NaN  1.100000e+09
# ..       ...      ...           ...
# 116   3500.0      NaN  3.850000e+09
# 117   2200.0      NaN  8.800000e+08
# 118   3500.0    Timur  4.300000e+09
# 119   2200.0  Selatan  3.400000e+09
# 120   3500.0    Timur  2.250000e+09
#
#                                                    URL  \
# 0    https://www.rumah.com/listing-properti/dijual-...
# 1    https://www.rumah.com/listing-properti/dijual-...
# 2    https://www.rumah.com/listing-properti/dijual-...
# 3    https://www.rumah.com/listing-properti/dijual-...
# 4    https://www.rumah.com/listing-properti/dijual-...
# ..                                                 ...
# 116  https://www.rumah.com/listing-properti/dijual-...
# 117  https://www.rumah.com/listing-properti/dijual-...
# 118  https://www.rumah.com/listing-properti/dijual-...
# 119  https://www.rumah.com/listing-properti/dijual-...
# 120  https://www.rumah.com/listing-properti/dijual-...
#
#                                              deskripsi
# 0    Dekat Cikini Salemba Taman Isamail Marzuki Kam...
# 1    Mengusung konsep minimalis, dan didukung denga...
# 2    Dekat dengan Mall Atrium Senen, dekat dengan a...
# 3    Berlokasi sangat strategis, sangat dekat ke Tu...
# 4    Bisa request ubah tata ruang, beli 2 unit mend...
# ..                                                 ...
# 116  Rumah Mewah siap huni 2 lantai 220m 10x22 type...
# 117  Rumah Signature Location & Access :\n• 2 Menit...
# 118  Rumah 1, 5 Lantai Luas Strategis di Pondok Bam...
# 119  Rumah Baru Non Komplek Posisi Hook Lokasi Stra...
# 120  Rumah Modern Minimalis dengan 2 lantai di Jati...
#
# [121 rows x 13 columns]

# %%
dfJ.duplicated().sum()
# Out:
# 0

# %%
dfJ.isnull().sum()
# Out:
# LT             0
# LB             0
# KT             0
# KM             0
# garasi        77
# carport       31
# lokasi         0
# sertifikat     2
# listrik        1
# hadap         85
# harga          0
# URL            0
# deskripsi      9
# dtype: int64

# %%
(dfJ.isnull().sum()/len(dfJ)).to_frame('persentase missing')
# Out:
#             persentase missing
# LT                    0.000000
# LB                    0.000000
# KT                    0.000000
# KM                    0.000000
# garasi                0.636364
# carport               0.256198
# lokasi                0.000000
# sertifikat            0.016529
# listrik               0.008264
# hadap                 0.702479
# harga                 0.000000
# URL                   0.000000
# deskripsi             0.074380

# %%
# Mengatasi missing value dengan drop karena variabel random (missing value sedikit)
dfJ.dropna(subset=["LT", "LB", "KT", "KM", "lokasi", "sertifikat", "URL", "listrik", "harga", "deskripsi"])
# Out:
#         LT     LB   KT   KM  garasi  carport         lokasi sertifikat  \
# 0    202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat        SHM
# 1     30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat        SHM
# 2     19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat        SHM
# 3     33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat        SHM
# 4     30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat        SHM
# ..     ...    ...  ...  ...     ...      ...            ...        ...
# 116  220.0  239.0  5.0  4.0     1.0      2.0  Jakarta Timur       PPJB
# 117   70.0   57.0  3.0  2.0     NaN      2.0  Jakarta Timur        SHM
# 118  315.0  280.0  4.0  3.0     1.0      2.0  Jakarta Timur  SHM + IMB
# 119  135.0  190.0  5.0  5.0     NaN      2.0  Jakarta Timur  SHM + IMB
# 120  144.0  250.0  5.0  5.0     NaN      2.0  Jakarta Timur        SHM
#
#      listrik    hadap         harga  \
# 0     2200.0      NaN  4.500000e+09
# 1     2200.0      NaN  1.100000e+09
# 2     2200.0      NaN  3.950000e+08
# 3     2200.0      NaN  8.350000e+08
# 4     2200.0      NaN  1.100000e+09
# ..       ...      ...           ...
# 116   3500.0      NaN  3.850000e+09
# 117   2200.0      NaN  8.800000e+08
# 118   3500.0    Timur  4.300000e+09
# 119   2200.0  Selatan  3.400000e+09
# 120   3500.0    Timur  2.250000e+09
#
#                                                    URL  \
# 0    https://www.rumah.com/listing-properti/dijual-...
# 1    https://www.rumah.com/listing-properti/dijual-...
# 2    https://www.rumah.com/listing-properti/dijual-...
# 3    https://www.rumah.com/listing-properti/dijual-...
# 4    https://www.rumah.com/listing-properti/dijual-...
# ..                                                 ...
# 116  https://www.rumah.com/listing-properti/dijual-...
# 117  https://www.rumah.com/listing-properti/dijual-...
# 118  https://www.rumah.com/listing-properti/dijual-...
# 119  https://www.rumah.com/listing-properti/dijual-...
# 120  https://www.rumah.com/listing-properti/dijual-...
#
#                                              deskripsi
# 0    Dekat Cikini Salemba Taman Isamail Marzuki Kam...
# 1    Mengusung konsep minimalis, dan didukung denga...
# 2    Dekat dengan Mall Atrium Senen, dekat dengan a...
# 3    Berlokasi sangat strategis, sangat dekat ke Tu...
# 4    Bisa request ubah tata ruang, beli 2 unit mend...
# ..                                                 ...
# 116  Rumah Mewah siap huni 2 lantai 220m 10x22 type...
# 117  Rumah Signature Location & Access :\n• 2 Menit...
# 118  Rumah 1, 5 Lantai Luas Strategis di Pondok Bam...
# 119  Rumah Baru Non Komplek Posisi Hook Lokasi Stra...
# 120  Rumah Modern Minimalis dengan 2 lantai di Jati...
#
# [109 rows x 13 columns]

# %%
# mengatasi missing value dengan mean karena tipe variabel data numerik
rata_garasi = dfJ['garasi'].mean()
dfJ['garasi'] = dfJ['garasi'].fillna(rata_garasi)
dfJ['garasi'].isna().sum()
# Out:
# 0

# %%
# mengatasi missing value dengan mean karena tipe variabel data numerik
rata_carport = dfJ['carport'].mean()
dfJ['carport'] = dfJ['carport'].fillna(rata_carport)
dfJ['carport'].isna().sum()
# Out:
# 0

# %%
# mengatasi missing value dengan mean karena tipe variabel data kategorik
modus_hadap = dfJ['hadap'].mode()[0]
dfJ['hadap'] = dfJ['hadap'].fillna(modus_hadap)
dfJ['hadap'].isna().sum()
# Out:
# 0

# %%
dfJ
# Out:
#         LT     LB   KT   KM    garasi   carport         lokasi sertifikat  \
# 0    202.0  198.0  8.0  3.0  1.863636  1.955556  Jakarta Pusat        SHM
# 1     30.0   55.0  2.0  1.0  1.863636  1.000000  Jakarta Pusat        SHM
# 2     19.0   35.0  2.0  1.0  1.863636  1.955556  Jakarta Pusat        SHM
# 3     33.0   42.0  2.0  2.0  1.863636  1.000000  Jakarta Pusat        SHM
# 4     30.0   55.0  2.0  2.0  1.863636  1.000000  Jakarta Pusat        SHM
# ..     ...    ...  ...  ...       ...       ...            ...        ...
# 116  220.0  239.0  5.0  4.0  1.000000  2.000000  Jakarta Timur       PPJB
# 117   70.0   57.0  3.0  2.0  1.863636  2.000000  Jakarta Timur        SHM
# 118  315.0  280.0  4.0  3.0  1.000000  2.000000  Jakarta Timur  SHM + IMB
# 119  135.0  190.0  5.0  5.0  1.863636  2.000000  Jakarta Timur  SHM + IMB
# 120  144.0  250.0  5.0  5.0  1.863636  2.000000  Jakarta Timur        SHM
#
#      listrik    hadap         harga  \
# 0     2200.0    Timur  4.500000e+09
# 1     2200.0    Timur  1.100000e+09
# 2     2200.0    Timur  3.950000e+08
# 3     2200.0    Timur  8.350000e+08
# 4     2200.0    Timur  1.100000e+09
# ..       ...      ...           ...
# 116   3500.0    Timur  3.850000e+09
# 117   2200.0    Timur  8.800000e+08
# 118   3500.0    Timur  4.300000e+09
# 119   2200.0  Selatan  3.400000e+09
# 120   3500.0    Timur  2.250000e+09
#
#                                                    URL  \
# 0    https://www.rumah.com/listing-properti/dijual-...
# 1    https://www.rumah.com/listing-properti/dijual-...
# 2    https://www.rumah.com/listing-properti/dijual-...
# 3    https://www.rumah.com/listing-properti/dijual-...
# 4    https://www.rumah.com/listing-properti/dijual-...
# ..                                                 ...
# 116  https://www.rumah.com/listing-properti/dijual-...
# 117  https://www.rumah.com/listing-properti/dijual-...
# 118  https://www.rumah.com/listing-properti/dijual-...
# 119  https://www.rumah.com/listing-properti/dijual-...
# 120  https://www.rumah.com/listing-properti/dijual-...
#
#                                              deskripsi
# 0    Dekat Cikini Salemba Taman Isamail Marzuki Kam...
# 1    Mengusung konsep minimalis, dan didukung denga...
# 2    Dekat dengan Mall Atrium Senen, dekat dengan a...
# 3    Berlokasi sangat strategis, sangat dekat ke Tu...
# 4    Bisa request ubah tata ruang, beli 2 unit mend...
# ..                                                 ...
# 116  Rumah Mewah siap huni 2 lantai 220m 10x22 type...
# 117  Rumah Signature Location & Access :\n• 2 Menit...
# 118  Rumah 1, 5 Lantai Luas Strategis di Pondok Bam...
# 119  Rumah Baru Non Komplek Posisi Hook Lokasi Stra...
# 120  Rumah Modern Minimalis dengan 2 lantai di Jati...
#
# [121 rows x 13 columns]

# %%
dfJ['KT'] = dfJ['KT'] .astype('int64')
dfJ['KM'] = dfJ['KM'] .astype('int64')
dfJ['garasi'] = dfJ['garasi'] .astype('int64')
dfJ['carport'] = dfJ['carport'] .astype('int64')
dfJ['lokasi'] = dfJ['lokasi'] .astype('category')
dfJ['sertifikat'] = dfJ['sertifikat'] .astype('category')
dfJ['listrik'] = dfJ['listrik'] .astype('category')
dfJ['hadap'] = dfJ['hadap'] .astype('category')
dfJ['harga'] = dfJ['harga'] .astype('int64')

dfJ.dtypes
# Out:
# LT             float64
# LB             float64
# KT               int64
# KM               int64
# garasi           int64
# carport          int64
# lokasi        category
# sertifikat    category
# listrik       category
# hadap         category
# harga            int64
# URL             object
# deskripsi       object
# dtype: object

# %%
dfJ
# Out:
#         LT     LB  KT  KM  garasi  carport         lokasi sertifikat listrik  \
# 0    202.0  198.0   8   3       1        1  Jakarta Pusat        SHM  2200.0
# 1     30.0   55.0   2   1       1        1  Jakarta Pusat        SHM  2200.0
# 2     19.0   35.0   2   1       1        1  Jakarta Pusat        SHM  2200.0
# 3     33.0   42.0   2   2       1        1  Jakarta Pusat        SHM  2200.0
# 4     30.0   55.0   2   2       1        1  Jakarta Pusat        SHM  2200.0
# ..     ...    ...  ..  ..     ...      ...            ...        ...     ...
# 116  220.0  239.0   5   4       1        2  Jakarta Timur       PPJB  3500.0
# 117   70.0   57.0   3   2       1        2  Jakarta Timur        SHM  2200.0
# 118  315.0  280.0   4   3       1        2  Jakarta Timur  SHM + IMB  3500.0
# 119  135.0  190.0   5   5       1        2  Jakarta Timur  SHM + IMB  2200.0
# 120  144.0  250.0   5   5       1        2  Jakarta Timur        SHM  3500.0
#
#        hadap       harga                                                URL  \
# 0      Timur  4500000000  https://www.rumah.com/listing-properti/dijual-...
# 1      Timur  1100000000  https://www.rumah.com/listing-properti/dijual-...
# 2      Timur   395000000  https://www.rumah.com/listing-properti/dijual-...
# 3      Timur   835000000  https://www.rumah.com/listing-properti/dijual-...
# 4      Timur  1100000000  https://www.rumah.com/listing-properti/dijual-...
# ..       ...         ...                                                ...
# 116    Timur  3850000000  https://www.rumah.com/listing-properti/dijual-...
# 117    Timur   880000000  https://www.rumah.com/listing-properti/dijual-...
# 118    Timur  4300000000  https://www.rumah.com/listing-properti/dijual-...
# 119  Selatan  3400000000  https://www.rumah.com/listing-properti/dijual-...
# 120    Timur  2250000000  https://www.rumah.com/listing-properti/dijual-...
#
#                                              deskripsi
# 0    Dekat Cikini Salemba Taman Isamail Marzuki Kam...
# 1    Mengusung konsep minimalis, dan didukung denga...
# 2    Dekat dengan Mall Atrium Senen, dekat dengan a...
# 3    Berlokasi sangat strategis, sangat dekat ke Tu...
# 4    Bisa request ubah tata ruang, beli 2 unit mend...
# ..                                                 ...
# 116  Rumah Mewah siap huni 2 lantai 220m 10x22 type...
# 117  Rumah Signature Location & Access :\n• 2 Menit...
# 118  Rumah 1, 5 Lantai Luas Strategis di Pondok Bam...
# 119  Rumah Baru Non Komplek Posisi Hook Lokasi Stra...
# 120  Rumah Modern Minimalis dengan 2 lantai di Jati...
#
# [121 rows x 13 columns]

# %% [markdown]
# # VISUALISASI

# %%
# Mengetahui hubungan antara variabel
dfJ.corr()
# Out:
#                LT        LB        KT        KM    garasi   carport     harga
# LT       1.000000  0.414775  0.178123  0.104909  0.259818  0.292076  0.390733
# LB       0.414775  1.000000  0.572796  0.581507  0.374305  0.562148  0.804563
# KT       0.178123  0.572796  1.000000  0.806234  0.169255  0.352171  0.375735
# KM       0.104909  0.581507  0.806234  1.000000  0.105066  0.387357  0.394783
# garasi   0.259818  0.374305  0.169255  0.105066  1.000000  0.012400  0.345484
# carport  0.292076  0.562148  0.352171  0.387357  0.012400  1.000000  0.578811
# harga    0.390733  0.804563  0.375735  0.394783  0.345484  0.578811  1.000000

# %%
p = sns.catplot(x="harga", data=dfJ)
p

# %%
p1 = sns.catplot(x="LB", y="harga", data=dfJ)
p1

# %% [markdown]
#  Kualitas data yang dimiliki perusahaan kurang baik, dikarenakan terdapat banyak informasi atau spesifikasi yang belum jelas atau kosong, sehingga perlu dilakukan drop/dropna atau penghapusan beberapa kolom dan baris pada data. Lalu ada baiknya DE/DBA ketika melakukan pengumpulan data untuk mencari informasi yang mendetail sehingga tidak ada data yang kosong agar RPPI menjadi data diven company yang unggul. Kemudian dari visualisasi di atas, sepertinya ada kecenderungan bahwa harga rumah di kota Depok lebih murah dibandingkan harga rumah di kota Jakarta, ada baiknya RPPI membuat kantor cabang berikutnya di Depok Di mana kota ini tersedia banyak harga rumah yang terjangkau. Lalu dari data yang ada, rumah dengan karakteristik adalah rumah yang paling banyak dijual.
# Jika RPPI ingin melakukan investasi max Rp.25 Milyar minggu besok, dari data, kita dapat memberikan rekomendasi rumah mana saja yang akan berpotensi menghasilkan keuntungan bagi perusahaan dikarenakan lokasinya yang strategis, yaitu terletak pada kawasan yang ramai dan mudah diakses. Serta rumah-rumah tersebut cukup luas dan memiliki fasilitas yang memadai sehingga berpotensi untuk dijadikan sebagai bisnis sewa yang akan menghasilkan keuntungan bagi perusahaan RPPI.

# %% [markdown]
# # Melihat informasi dari data csv Depok

# %%
N, P = dfD.shape # Ukuran Data
print('baris = ', N, ', Kolom (jumlah variabel) = ', P)
print("Tipe Variabe df = ", type(dfD))
# "Melihat" beberapa data pertamanya
dfD.head()
# Out:
# baris =  118 , Kolom (jumlah variabel) =  13
# Tipe Variabe df =  <class 'pandas.core.frame.DataFrame'>
#     LT     LB  KT  KM  garasi  carport     lokasi sertifikat listrik    hadap  \
# 0  165  200.0   4   2       1        1  Sukmajaya        SHM  2200.0  Selatan
# 1   50   45.0   2   1       1        1   Cipayung        SHM  1300.0    Utara
# 2   50   36.0   2   1       1        1   Sawangan        SHM  1300.0    Barat
# 3   50   45.0   2   1       1        1  Cimanggis        SHM  1300.0    Utara
# 4   72   45.0   2   1       1        1   Sawangan        SHM  1300.0    Timur
#
#    harga                                                URL  \
# 0   2100  https://www.rumah123.com/properti/depok/hos928...
# 1    250  https://www.rumah123.com/properti/depok/hos928...
# 2    250  https://www.rumah123.com/properti/depok/hos928...
# 3    250  https://www.rumah123.com/properti/depok/hos928...
# 4    350  https://www.rumah123.com/properti/depok/hos928...
#
#                                           deskripsi
# 0                     Rumah siap huni komplek Pelni
# 1               rumah minimalis termurah di citayam
# 2           CLUSTER TERMURAH DI SAWANGAN KOTA DEPOK
# 3  RUMAH SIAP HUNI HARGA NEGO DEKAT STASIUN CITAYAM
# 4                     Rumah Cluster Siap Huni Depok

# %%
dfD.tail()
# Out:
#       LT     LB  KT  KM  garasi  carport     lokasi sertifikat listrik  \
# 113   79  115.0   2   1       1        1  Sukmajaya        SHM  2200.0
# 114   72   45.0   2   1       1        1  Cimanggis        SHM  2200.0
# 115   40   40.0   2   1       1        1   Cipayung        SHM  1300.0
# 116   50   50.0   2   1       1        1   Cipayung        SHM  1300.0
# 117  100   15.0   3   3       1        1     Cinere        SHM  3500.0
#
#        hadap  harga                                                URL  \
# 113    Utara    750  https://www.rumah123.com/properti/depok/hos928...
# 114    Utara   1000  https://www.rumah123.com/properti/depok/hos928...
# 115    Timur    195  https://www.rumah123.com/properti/depok/hos928...
# 116  Selatan    185  https://www.rumah123.com/properti/depok/hos927...
# 117    Utara   1750  https://www.rumah123.com/properti/depok/hos928...
#
#                                              deskripsi
# 113                               Rumah di Depok Timur
# 114                      PERUMAHAN NUANSA PERMAI DEPOK
# 115  rumah semi minimalis manis harga ekonomis di c...
# 116  rumah semi minimalis dua kamar siap huni di ci...
# 117                 Dijual cepat rumah bagus siap huni

# %%
dfD.sample(15)
# Out:
#     created_at   LT     LB   KT   KM  garasi  carport        lokasi  \
# 55   5-12-2021   92  110.0  3.0  1.0     1.0      1.0        Cinere
# 233        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 595        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 226        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 662        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 145        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 718        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 547        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 393        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 341        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 621        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 136        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 321        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
# 79   5-12-2021   63   61.0  3.0  2.0     NaN      2.0  Pancoran Mas
# 849        NaN  NaN    NaN  NaN  NaN     NaN      NaN           NaN
#
#     sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 55         SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 233        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 595        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 226        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 662        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 145        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 718        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 547        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 393        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 341        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 621        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 136        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 321        NaN      NaN  ...         NaN          NaN         NaN         NaN
# 79         SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 849        NaN      NaN  ...         NaN          NaN         NaN         NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 55           NaN          NaN          NaN          NaN          NaN
# 233          NaN          NaN          NaN          NaN          NaN
# 595          NaN          NaN          NaN          NaN          NaN
# 226          NaN          NaN          NaN          NaN          NaN
# 662          NaN          NaN          NaN          NaN          NaN
# 145          NaN          NaN          NaN          NaN          NaN
# 718          NaN          NaN          NaN          NaN          NaN
# 547          NaN          NaN          NaN          NaN          NaN
# 393          NaN          NaN          NaN          NaN          NaN
# 341          NaN          NaN          NaN          NaN          NaN
# 621          NaN          NaN          NaN          NaN          NaN
# 136          NaN          NaN          NaN          NaN          NaN
# 321          NaN          NaN          NaN          NaN          NaN
# 79           NaN          NaN          NaN          NaN          NaN
# 849          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 25
# 55           NaN
# 233          NaN
# 595          NaN
# 226          NaN
# 662          NaN
# 145          NaN
# 718          NaN
# 547          NaN
# 393          NaN
# 341          NaN
# 621          NaN
# 136          NaN
# 321          NaN
# 79           NaN
# 849          NaN
#
# [15 rows x 26 columns]

# %%
# drop kolom yang tidak terpakai
dfD.drop(["created_at","Unnamed: 14","Unnamed: 15","Unnamed: 16","Unnamed: 17","Unnamed: 18",
          "Unnamed: 19","Unnamed: 20","Unnamed: 21","Unnamed: 22","Unnamed: 23",
          "Unnamed: 24","Unnamed: 25"], axis=1, inplace=True)
dfD.head()
# Out:
#     LT     LB   KT   KM  garasi  carport     lokasi sertifikat  listrik  \
# 0  165  200.0  4.0  2.0     NaN      1.0  Sukmajaya        SHM   2200.0
# 1   50   45.0  2.0  1.0     NaN      NaN   Cipayung        SHM   1300.0
# 2   50   36.0  2.0  1.0     NaN      1.0   Sawangan        SHM   1300.0
# 3   50   45.0  2.0  1.0     NaN      NaN  Cimanggis        SHM   1300.0
# 4   72   45.0  2.0  1.0     NaN      1.0   Sawangan        SHM   1300.0
#
#      hadap   harga                                                URL  \
# 0  Selatan  2100.0  https://www.rumah123.com/properti/depok/hos928...
# 1      NaN   250.0  https://www.rumah123.com/properti/depok/hos928...
# 2    Barat   250.0  https://www.rumah123.com/properti/depok/hos928...
# 3      NaN   250.0  https://www.rumah123.com/properti/depok/hos928...
# 4    Timur   350.0  https://www.rumah123.com/properti/depok/hos928...
#
#                                           deskripsi
# 0                     Rumah siap huni komplek Pelni
# 1               rumah minimalis termurah di citayam
# 2           CLUSTER TERMURAH DI SAWANGAN KOTA DEPOK
# 3  RUMAH SIAP HUNI HARGA NEGO DEKAT STASIUN CITAYAM
# 4                     Rumah Cluster Siap Huni Depok

# %%
dfD.drop(dfD.tail(880).index,inplace=True)

# %%
dfD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 0 to 117
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LT          118 non-null    object
#  1   LB          118 non-null    float64
#  2   KT          118 non-null    float64
#  3   KM          118 non-null    float64
#  4   garasi      25 non-null     float64
#  5   carport     94 non-null     float64
#  6   lokasi      118 non-null    object
#  7   sertifikat  118 non-null    object
#  8   listrik     103 non-null    float64
#  9   hadap       62 non-null     object
#  10  harga       118 non-null    float64
#  11  URL         118 non-null    object
#  12  deskripsi   118 non-null    object
# dtypes: float64(7), object(6)
# memory usage: 12.9+ KB

# %%
dfD
# Out:
#       LT     LB   KT   KM  garasi  carport     lokasi sertifikat  listrik  \
# 0    165  200.0  4.0  2.0     NaN      1.0  Sukmajaya        SHM   2200.0
# 1     50   45.0  2.0  1.0     NaN      NaN   Cipayung        SHM   1300.0
# 2     50   36.0  2.0  1.0     NaN      1.0   Sawangan        SHM   1300.0
# 3     50   45.0  2.0  1.0     NaN      NaN  Cimanggis        SHM   1300.0
# 4     72   45.0  2.0  1.0     NaN      1.0   Sawangan        SHM   1300.0
# ..   ...    ...  ...  ...     ...      ...        ...        ...      ...
# 113   79  115.0  2.0  1.0     1.0      1.0  Sukmajaya        SHM      NaN
# 114   72   45.0  2.0  1.0     NaN      1.0  Cimanggis        SHM      NaN
# 115   40   40.0  2.0  1.0     NaN      NaN   Cipayung        SHM   1300.0
# 116   50   50.0  2.0  1.0     NaN      NaN   Cipayung        SHM   1300.0
# 117  100   15.0  3.0  3.0     1.0      1.0     Cinere        SHM   3500.0
#
#        hadap   harga                                                URL  \
# 0    Selatan  2100.0  https://www.rumah123.com/properti/depok/hos928...
# 1        NaN   250.0  https://www.rumah123.com/properti/depok/hos928...
# 2      Barat   250.0  https://www.rumah123.com/properti/depok/hos928...
# 3        NaN   250.0  https://www.rumah123.com/properti/depok/hos928...
# 4      Timur   350.0  https://www.rumah123.com/properti/depok/hos928...
# ..       ...     ...                                                ...
# 113      NaN   750.0  https://www.rumah123.com/properti/depok/hos928...
# 114      NaN  1000.0  https://www.rumah123.com/properti/depok/hos928...
# 115    Timur   195.0  https://www.rumah123.com/properti/depok/hos928...
# 116  Selatan   185.0  https://www.rumah123.com/properti/depok/hos927...
# 117      NaN  1750.0  https://www.rumah123.com/properti/depok/hos928...
#
#                                              deskripsi
# 0                        Rumah siap huni komplek Pelni
# 1                  rumah minimalis termurah di citayam
# 2              CLUSTER TERMURAH DI SAWANGAN KOTA DEPOK
# 3     RUMAH SIAP HUNI HARGA NEGO DEKAT STASIUN CITAYAM
# 4                        Rumah Cluster Siap Huni Depok
# ..                                                 ...
# 113                               Rumah di Depok Timur
# 114                      PERUMAHAN NUANSA PERMAI DEPOK
# 115  rumah semi minimalis manis harga ekonomis di c...
# 116  rumah semi minimalis dua kamar siap huni di ci...
# 117                 Dijual cepat rumah bagus siap huni
#
# [118 rows x 13 columns]

# %%
dfD.duplicated().sum()
# Out:
# 0

# %%
dfD.isnull().sum()
# Out:
# LT             0
# LB             0
# KT             0
# KM             0
# garasi        93
# carport       24
# lokasi         0
# sertifikat     0
# listrik       15
# hadap         56
# harga          0
# URL            0
# deskripsi      0
# dtype: int64

# %%
(dfD.isnull().sum()/len(dfD)).to_frame('persentase missing')
# Out:
#             persentase missing
# LT                    0.000000
# LB                    0.000000
# KT                    0.000000
# KM                    0.000000
# garasi                0.788136
# carport               0.203390
# lokasi                0.000000
# sertifikat            0.000000
# listrik               0.127119
# hadap                 0.474576
# harga                 0.000000
# URL                   0.000000
# deskripsi             0.000000

# %%
# mengatasi missing value dengan mean karena tipe variabel data kategorik
modus_listrik = dfD['listrik'].mode()[0]
dfD['listrik'] = dfD['listrik'].fillna(modus_listrik)
dfD['listrik'].isna().sum()
# Out:
# 0

# %%
# mengatasi missing value dengan mean karena tipe variabel data numerik
rata_garasi = dfD['garasi'].mean()
dfD['garasi'] = dfD['garasi'].fillna(rata_garasi)
dfD['garasi'].isna().sum()
# Out:
# 0

# %%
# mengatasi missing value dengan mean karena tipe variabel data numerik
rata_carport = dfD['carport'].mean()
dfD['carport'] = dfD['carport'].fillna(rata_carport)
dfD['carport'].isna().sum()
# Out:
# 0

# %%
# mengatasi missing value dengan mean karena tipe variabel data kategorik
modus_hadap = dfD['hadap'].mode()[0]
dfD['hadap'] = dfD['hadap'].fillna(modus_hadap)
dfD['hadap'].isna().sum()
# Out:
# 0

# %%
dfD
# Out:
#       LT     LB   KT   KM  garasi   carport     lokasi sertifikat  listrik  \
# 0    165  200.0  4.0  2.0    1.76  1.000000  Sukmajaya        SHM   2200.0
# 1     50   45.0  2.0  1.0    1.76  1.670213   Cipayung        SHM   1300.0
# 2     50   36.0  2.0  1.0    1.76  1.000000   Sawangan        SHM   1300.0
# 3     50   45.0  2.0  1.0    1.76  1.670213  Cimanggis        SHM   1300.0
# 4     72   45.0  2.0  1.0    1.76  1.000000   Sawangan        SHM   1300.0
# ..   ...    ...  ...  ...     ...       ...        ...        ...      ...
# 113   79  115.0  2.0  1.0    1.00  1.000000  Sukmajaya        SHM   2200.0
# 114   72   45.0  2.0  1.0    1.76  1.000000  Cimanggis        SHM   2200.0
# 115   40   40.0  2.0  1.0    1.76  1.670213   Cipayung        SHM   1300.0
# 116   50   50.0  2.0  1.0    1.76  1.670213   Cipayung        SHM   1300.0
# 117  100   15.0  3.0  3.0    1.00  1.000000     Cinere        SHM   3500.0
#
#        hadap   harga                                                URL  \
# 0    Selatan  2100.0  https://www.rumah123.com/properti/depok/hos928...
# 1      Utara   250.0  https://www.rumah123.com/properti/depok/hos928...
# 2      Barat   250.0  https://www.rumah123.com/properti/depok/hos928...
# 3      Utara   250.0  https://www.rumah123.com/properti/depok/hos928...
# 4      Timur   350.0  https://www.rumah123.com/properti/depok/hos928...
# ..       ...     ...                                                ...
# 113    Utara   750.0  https://www.rumah123.com/properti/depok/hos928...
# 114    Utara  1000.0  https://www.rumah123.com/properti/depok/hos928...
# 115    Timur   195.0  https://www.rumah123.com/properti/depok/hos928...
# 116  Selatan   185.0  https://www.rumah123.com/properti/depok/hos927...
# 117    Utara  1750.0  https://www.rumah123.com/properti/depok/hos928...
#
#                                              deskripsi
# 0                        Rumah siap huni komplek Pelni
# 1                  rumah minimalis termurah di citayam
# 2              CLUSTER TERMURAH DI SAWANGAN KOTA DEPOK
# 3     RUMAH SIAP HUNI HARGA NEGO DEKAT STASIUN CITAYAM
# 4                        Rumah Cluster Siap Huni Depok
# ..                                                 ...
# 113                               Rumah di Depok Timur
# 114                      PERUMAHAN NUANSA PERMAI DEPOK
# 115  rumah semi minimalis manis harga ekonomis di c...
# 116  rumah semi minimalis dua kamar siap huni di ci...
# 117                 Dijual cepat rumah bagus siap huni
#
# [118 rows x 13 columns]

# %%
dfD['KT'] = dfD['KT'] .astype('int64')
dfD['KM'] = dfD['KM'] .astype('int64')
dfD['garasi'] = dfD['garasi'] .astype('int64')
dfD['carport'] = dfD['carport'] .astype('int64')
dfD['lokasi'] = dfD['lokasi'] .astype('category')
dfD['sertifikat'] = dfD['sertifikat'] .astype('category')
dfD['listrik'] = dfD['listrik'] .astype('category')
dfD['hadap'] = dfD['hadap'] .astype('category')
dfD['harga'] = dfD['harga'] .astype('int64')

dfD.dtypes
# Out:
# LT              object
# LB             float64
# KT               int64
# KM               int64
# garasi           int64
# carport          int64
# lokasi        category
# sertifikat    category
# listrik       category
# hadap         category
# harga            int64
# URL             object
# deskripsi       object
# dtype: object

# %% [markdown]
# #  VISUALISASI

# %%
q = sns.catplot(x="harga", data=dfD)
q

# %% [markdown]
# # Melihat informasi dari data csv Tangerang

# %%
N, P = dfT.shape # Ukuran Data
print('baris = ', N, ', Kolom (jumlah variabel) = ', P)
print("Tipe Variabe df = ", type(dfT))
# "Melihat" beberapa data pertamanya
dfT.head(9)

# %%
dfT.tail()

# %%
dfT.sample(15)

# %%
# drop kolom yang tidak terpakai
dfT.drop(["created_at","Unnamed: 14","Unnamed: 15","Unnamed: 16","Unnamed: 17","Unnamed: 18",
          "Unnamed: 19","Unnamed: 20","Unnamed: 21","Unnamed: 22","Unnamed: 23",
          "Unnamed: 24","Unnamed: 25"], axis=1, inplace=True)
dfT.head()

# %%
dfT.drop(dfT.tail(4).index,inplace=True)

# %%
dfT

# %%
dfT.duplicated().sum()

# %%
#drop duplicated data
dfT.drop_duplicates(inplace=True) 
print(dfT.duplicated().sum()) 
print(dfT.shape)

# %%
print(dfT.isnull().sum())

# %%
(dfJ.isnull().sum()/len(dfJ)).to_frame('persentase missing')

# %%
# Mengatasi missing value dengan drop karena variabel random (missing value sedikit)
dfJ.dropna(subset=["LT", "LB", "KT", "KM", "lokasi", "sertifikat", "URL", "listrik", "harga", "deskripsi"])

# %%
# mengatasi missing value dengan mean karena tipe variabel data numerik
rata_garasi = dfJ['garasi'].mean()
dfJ['garasi'] = dfJ['garasi'].fillna(rata_garasi)
dfJ['garasi'].isna().sum()

# %%
# mengatasi missing value dengan mean karena tipe variabel data numerik
rata_carport = dfJ['carport'].mean()
dfJ['carport'] = dfJ['carport'].fillna(rata_carport)
dfJ['carport'].isna().sum()

# %%
# mengatasi missing value dengan mean karena tipe variabel data kategorik
modus_hadap = dfJ['hadap'].mode()[0]
dfJ['hadap'] = dfJ['hadap'].fillna(modus_hadap)
dfJ['hadap'].isna().sum()

# %%
dfT

# %%
dfT['KT'] = dfT['KT'] .astype('int64')
dfT['KM'] = dfT['KM'] .astype('int64')
dfT['garasi'] = dfT['garasi'] .astype('int64')
dfT['carport'] = dfT['carport'] .astype('int64')
dfT['lokasi'] = dfT['lokasi'] .astype('category')
dfT['sertifikat'] = dfT['sertifikat'] .astype('category')
dfT['listrik'] = dfT['listrik'] .astype('category')
dfT['hadap'] = dfT['hadap'] .astype('category')
dfT['harga'] = dfT['harga'] .astype('int64')

dfT.dtypes

# %% [markdown]
# # VISUALISASI

# %%
r = sns.catplot(x="harga", data=dfT)
r
